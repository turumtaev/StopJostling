# %%
root@C.12993974:/temp/nanoGPT$ python calculate_metrics_and_save_ppl.py --out_dir=out/baseline
Overriding: out_dir = out/baseline
number of parameters: 10.67M
Results loaded successfully.
---
batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 62.56it/s]
batch: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 826.79it/s]
lang: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 19.18it/s]
language: big, metrics: accuracy: 0.5824788212776184
language: big, metrics: recall@5: 0.864776611328125
language: big, metrics: mrr: 0.7045679688453674
language: small, metrics: accuracy: 0.3861897885799408
language: small, metrics: recall@5: 0.7349141240119934
language: small, metrics: mrr: 0.5402751564979553
---
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:02<00:00, 78.70it/s]
lang: small, PPL(T=1): 8.332614139747925, PPL_min(T=1.13): 8.234632427422063
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:02<00:00, 81.65it/s]
lang: big, PPL(T=1): 4.100554639999456, PPL_min(T=1.28): 3.9545720337646086
---
PPLs saved to out/baseline/ppls.pth

# %%
root@C.12993974:/temp/nanoGPT$ python calculate_metrics_and_save_ppl.py --out_dir=out/out/proposed_margin_8.0
Overriding: out_dir = out/out/proposed_margin_8.0
number of parameters: 10.67M
Results loaded successfully.
---
batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 62.22it/s]
batch: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 830.77it/s]
lang: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 19.09it/s]
language: big, metrics: accuracy: 0.5814208984375
language: big, metrics: recall@5: 0.865753173828125
language: big, metrics: mrr: 0.7037239074707031
language: small, metrics: accuracy: 0.3864847719669342
language: small, metrics: recall@5: 0.729461669921875
language: small, metrics: mrr: 0.5391843914985657
---
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:02<00:00, 78.19it/s]
lang: small, PPL(T=1): 8.425582338395094, PPL_min(T=1.17): 8.252142617341072
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:02<00:00, 81.75it/s]
lang: big, PPL(T=1): 4.119892601846044, PPL_min(T=1.26): 3.9761924144507943
---
PPLs saved to out/out/proposed_margin_8.0/ppls.pth
root@C.12993974:/temp/nanoGPT$ python eval.py --out_dir= out/out/proposed_margin_8.0

# %%
root@C.12993974:/temp/nanoGPT$ python calculate_metrics_and_save_ppl.py --out_dir=out/out/proposed_margin_4.0
Overriding: out_dir = out/out/proposed_margin_4.0
number of parameters: 10.67M
Results loaded successfully.
---
batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 45.91it/s]
batch: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 712.19it/s]
lang: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 14.23it/s]
language: big, metrics: accuracy: 0.5840962529182434
language: big, metrics: recall@5: 0.8643900752067566
language: big, metrics: mrr: 0.7057122588157654
language: small, metrics: accuracy: 0.39691162109375
language: small, metrics: recall@5: 0.74481201171875
language: small, metrics: mrr: 0.5500498414039612
---
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:02<00:00, 77.39it/s]
lang: small, PPL(T=1): 8.048989320232536, PPL_min(T=1.06): 8.018984442137043
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:02<00:00, 80.96it/s]
lang: big, PPL(T=1): 4.028400410363222, PPL_min(T=1.1): 3.9978505342232658
---
PPLs saved to out/out/proposed_margin_4.0/ppls.pth

# %%
root@C.12993974:/temp/nanoGPT$ python calculate_metrics_and_save_ppl.py --out_dir=out/out/proposed_margin_2.0
Overriding: out_dir = out/out/proposed_margin_2.0
number of parameters: 10.67M
Results loaded successfully.
---
batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 62.27it/s]
batch: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 827.52it/s]
lang: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 19.10it/s]
language: big, metrics: accuracy: 0.5880839228630066
language: big, metrics: recall@5: 0.8613789677619934
language: big, metrics: mrr: 0.7068817019462585
language: small, metrics: accuracy: 0.4318033754825592
language: small, metrics: recall@5: 0.7768656611442566
language: small, metrics: mrr: 0.5815240740776062
---
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:02<00:00, 78.87it/s]
lang: small, PPL(T=1): 7.47189888276563, PPL_min(T=0.81): 7.1130514430194625
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:02<00:00, 81.59it/s]
lang: big, PPL(T=1): 4.200971080970494, PPL_min(T=0.89): 4.1361661455117575
---
PPLs saved to out/out/proposed_margin_2.0/ppls.pth

# %%
root@C.12993974:/temp/nanoGPT$ python calculate_metrics_and_save_ppl.py --out_dir=out/out/proposed_margin_1.0
Overriding: out_dir = out/out/proposed_margin_1.0
number of parameters: 10.67M
Results loaded successfully.
---
batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 62.09it/s]
batch: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 828.86it/s]
lang: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 19.05it/s]
language: big, metrics: accuracy: 0.5873820185661316
language: big, metrics: recall@5: 0.8559163212776184
language: big, metrics: mrr: 0.7044277191162109
language: small, metrics: accuracy: 0.4509786069393158
language: small, metrics: recall@5: 0.7951863408088684
language: small, metrics: mrr: 0.599158763885498
---
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:02<00:00, 78.06it/s]
lang: small, PPL(T=1): 9.881303998901696, PPL_min(T=0.54): 6.558583416716536
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:02<00:00, 81.78it/s]
lang: big, PPL(T=1): 5.329965530412752, PPL_min(T=0.65): 4.364111596155809
---
PPLs saved to out/out/proposed_margin_1.0/ppls.pth

# %%
root@C.12993974:/temp/nanoGPT$ python calculate_metrics_and_save_ppl.py --out_dir=out/out/proposed_margin_0.5
Overriding: out_dir = out/out/proposed_margin_0.5
number of parameters: 10.67M
Results loaded successfully.
---
batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 61.43it/s]
batch: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 828.12it/s]
lang: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 18.86it/s]
language: big, metrics: accuracy: 0.590911865234375
language: big, metrics: recall@5: 0.8619486689567566
language: big, metrics: mrr: 0.708626925945282
language: small, metrics: accuracy: 0.447174072265625
language: small, metrics: recall@5: 0.7944539189338684
language: small, metrics: mrr: 0.5973572134971619
---
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:02<00:00, 77.83it/s]
lang: small, PPL(T=1): 19.53608244465596, PPL_min(T=0.33): 6.721189531286993
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:02<00:00, 81.60it/s]
lang: big, PPL(T=1): 12.010302479004388, PPL_min(T=0.36): 4.410167570165918
---
PPLs saved to out/out/proposed_margin_0.5/ppls.pth

# %%
root@C.12993974:/temp/nanoGPT$ python calculate_metrics_and_save_ppl.py --out_dir=out/out/proposed_margin_8.0_SE --separated_embeddings=True
Overriding: out_dir = out/out/proposed_margin_8.0_SE
Overriding: separated_embeddings = True
number of parameters: 10.67M
Results loaded successfully.
---
batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 61.89it/s]
batch: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 826.52it/s]
lang: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 18.99it/s]
language: big, metrics: accuracy: 0.58258056640625
language: big, metrics: recall@5: 0.8649088740348816
language: big, metrics: mrr: 0.7046213746070862
language: small, metrics: accuracy: 0.3857523500919342
language: small, metrics: recall@5: 0.7475993037223816
language: small, metrics: mrr: 0.5450162291526794
---
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:02<00:00, 78.17it/s]
lang: small, PPL(T=1): 7.9635540945953736, PPL_min(T=1.13): 7.859633065476865
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:02<00:00, 81.53it/s]
lang: big, PPL(T=1): 4.118162879643247, PPL_min(T=1.28): 3.962038694034198
---
PPLs saved to out/out/proposed_margin_8.0_SE/ppls.pth

# %%
root@C.12993974:/temp/nanoGPT$ python calculate_metrics_and_save_ppl.py --out_dir=out/out/proposed_margin_4.0_SE --separated_embeddings=True 
Overriding: out_dir = out/out/proposed_margin_4.0_SE
Overriding: separated_embeddings = True
number of parameters: 10.67M
Results loaded successfully.
---
batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 25.30it/s]
batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 58.34it/s]
lang: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  5.86it/s]
language: big, metrics: accuracy: 0.58245849609375
language: big, metrics: recall@5: 0.86492919921875
language: big, metrics: mrr: 0.7046048045158386
language: small, metrics: accuracy: 0.3955281674861908
language: small, metrics: recall@5: 0.7515360713005066
language: small, metrics: mrr: 0.5533478856086731
---
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:25<00:00,  7.72it/s]
lang: small, PPL(T=1): 7.740289818110736, PPL_min(T=1.0): 7.740289818110736
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:18<00:00, 10.88it/s]
lang: big, PPL(T=1): 4.037356340624286, PPL_min(T=1.1): 4.004417965329395
---
PPLs saved to out/out/proposed_margin_4.0_SE/ppls.pth

# %%
root@C.12993974:/temp/nanoGPT$ python calculate_metrics_and_save_ppl.py --out_dir=out/out/proposed_margin_2.0_SE --separated_embeddings=True
Overriding: out_dir = out/out/proposed_margin_2.0_SE
Overriding: separated_embeddings = True
number of parameters: 10.67M
Results loaded successfully.
---
batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 44.97it/s]
batch: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 199.90it/s]
lang: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 12.14it/s]
language: big, metrics: accuracy: 0.5889180302619934
language: big, metrics: recall@5: 0.86175537109375
language: big, metrics: mrr: 0.7074685096740723
language: small, metrics: accuracy: 0.4371846616268158
language: small, metrics: recall@5: 0.78045654296875
language: small, metrics: mrr: 0.5856379866600037
---
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:08<00:00, 24.70it/s]
lang: small, PPL(T=1): 7.26217482898165, PPL_min(T=0.8): 6.86795350866658
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:08<00:00, 23.98it/s]
lang: big, PPL(T=1): 4.205022376300659, PPL_min(T=0.88): 4.13367245929864
---
PPLs saved to out/out/proposed_margin_2.0_SE/ppls.pth

# %%
root@C.12993974:/temp/nanoGPT$ python calculate_metrics_and_save_ppl.py --out_dir=out/out/proposed_margin_1.0_SE --separated_embeddings=True
Overriding: out_dir = out/out/proposed_margin_1.0_SE
Overriding: separated_embeddings = True
number of parameters: 10.67M
Results loaded successfully.
---
batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 61.73it/s]
batch: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 824.70it/s]
lang: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 18.94it/s]
language: big, metrics: accuracy: 0.5867512822151184
language: big, metrics: recall@5: 0.856964111328125
language: big, metrics: mrr: 0.7041757702827454
language: small, metrics: accuracy: 0.4558309018611908
language: small, metrics: recall@5: 0.792510986328125
language: small, metrics: mrr: 0.6020128726959229
---
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:02<00:00, 78.11it/s]
lang: small, PPL(T=1): 9.901939128995464, PPL_min(T=0.54): 6.58694078495273
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:02<00:00, 81.63it/s]
lang: big, PPL(T=1): 5.398539410889068, PPL_min(T=0.64): 4.363427183924872
---
PPLs saved to out/out/proposed_margin_1.0_SE/ppls.pth

# %%
root@C.12993974:/temp/nanoGPT$ python calculate_metrics_and_save_ppl.py --out_dir=out/out/proposed_margin_0.9_SE --separated_embeddings=True
Overriding: out_dir = out/out/proposed_margin_0.9_SE
Overriding: separated_embeddings = True
number of parameters: 10.67M
Results loaded successfully.
---
batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 59.70it/s]
batch: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 822.95it/s]
lang: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 18.39it/s]
language: big, metrics: accuracy: 0.587860107421875
language: big, metrics: recall@5: 0.85748291015625
language: big, metrics: mrr: 0.7050046324729919
language: small, metrics: accuracy: 0.4527181088924408
language: small, metrics: recall@5: 0.7947590947151184
language: small, metrics: mrr: 0.6008197665214539
---
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:02<00:00, 78.08it/s]
lang: small, PPL(T=1): 11.130625397276445, PPL_min(T=0.49): 6.604836499566988
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:02<00:00, 81.75it/s]
lang: big, PPL(T=1): 5.87374228324619, PPL_min(T=0.59): 4.340328282834747
---
PPLs saved to out/out/proposed_margin_0.9_SE/ppls.pth

# %%
root@C.12993974:/temp/nanoGPT$ python calculate_metrics_and_save_ppl.py --out_dir=out/out/proposed_margin_0.8_SE --separated_embeddings=True
Overriding: out_dir = out/out/proposed_margin_0.8_SE
Overriding: separated_embeddings = True
number of parameters: 10.67M
Results loaded successfully.
---
batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 62.61it/s]
batch: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 824.46it/s]
lang: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 19.19it/s]
language: big, metrics: accuracy: 0.588531494140625
language: big, metrics: recall@5: 0.8569132685661316
language: big, metrics: mrr: 0.7059136033058167
language: small, metrics: accuracy: 0.4541117250919342
language: small, metrics: recall@5: 0.79400634765625
language: small, metrics: mrr: 0.6021919846534729
---
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:02<00:00, 77.76it/s]
lang: small, PPL(T=1): 11.99191584980308, PPL_min(T=0.47): 6.561847776274644
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:02<00:00, 81.48it/s]
lang: big, PPL(T=1): 6.5687918120960225, PPL_min(T=0.54): 4.3524305548779685
---
PPLs saved to out/out/proposed_margin_0.8_SE/ppls.pth

# %%
Overriding: separated_embeddings = True
number of parameters: 10.67M
Results loaded successfully.
---
batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 62.11it/s]
batch: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 822.63it/s]
lang: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 19.04it/s]
language: big, metrics: accuracy: 0.590545654296875
language: big, metrics: recall@5: 0.8597208857536316
language: big, metrics: mrr: 0.7074050903320312
language: small, metrics: accuracy: 0.454925537109375
language: small, metrics: recall@5: 0.7894185185432434
language: small, metrics: mrr: 0.6004539132118225
---
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:02<00:00, 78.33it/s]
lang: small, PPL(T=1): 13.987231122170588, PPL_min(T=0.43): 6.7318460264303415
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:02<00:00, 81.58it/s]
lang: big, PPL(T=1): 7.695385805292793, PPL_min(T=0.48): 4.3722621223116915
---
PPLs saved to out/out/proposed_margin_0.7_SE/ppls.pth

# %%
root@C.12993974:/temp/nanoGPT$ python calculate_metrics_and_save_ppl.py --out_dir=out/out/proposed_margin_0.6_SE --separated_embeddings=True
Overriding: out_dir = out/out/proposed_margin_0.6_SE
Overriding: separated_embeddings = True
number of parameters: 10.67M
Results loaded successfully.
---
batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 36.73it/s]
batch: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 116.80it/s]
lang: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  9.27it/s]
language: big, metrics: accuracy: 0.58917236328125
language: big, metrics: recall@5: 0.861785888671875
language: big, metrics: mrr: 0.7073521614074707
language: small, metrics: accuracy: 0.4517822265625
language: small, metrics: recall@5: 0.7934163212776184
language: small, metrics: mrr: 0.5995883941650391
---
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:09<00:00, 21.99it/s]
lang: small, PPL(T=1): 16.43272547273964, PPL_min(T=0.38): 6.66811597296239
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:05<00:00, 36.42it/s]
lang: big, PPL(T=1): 9.61762362994856, PPL_min(T=0.41): 4.413308014423732
---
PPLs saved to out/out/proposed_margin_0.6_SE/ppls.pth

# %%
root@C.12993974:/temp/nanoGPT$ python calculate_metrics_and_save_ppl.py --out_dir=out/out/proposed_margin_0.5_SE --separated_embeddings=True
Overriding: out_dir = out/out/proposed_margin_0.5_SE
Overriding: separated_embeddings = True
number of parameters: 10.67M
Results loaded successfully.
---
batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 22.09it/s]
batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 47.40it/s]
lang: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  5.01it/s]
language: big, metrics: accuracy: 0.5905964970588684
language: big, metrics: recall@5: 0.862152099609375
language: big, metrics: mrr: 0.7085766196250916
language: small, metrics: accuracy: 0.453521728515625
language: small, metrics: recall@5: 0.7917988896369934
language: small, metrics: mrr: 0.6001636981964111
---
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:26<00:00,  7.66it/s]
lang: small, PPL(T=1): 19.556694605442292, PPL_min(T=0.33): 6.69828441068929
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:25<00:00,  7.80it/s]
lang: big, PPL(T=1): 12.304474735421126, PPL_min(T=0.35): 4.414320448689344
---
PPLs saved to out/out/proposed_margin_0.5_SE/ppls.pth

# %%
root@C.12993974:/temp/nanoGPT$ python calculate_metrics_and_save_ppl.py --out_dir=out/baseline_eval_on_small
Overriding: out_dir = out/baseline_eval_on_small
number of parameters: 10.67M
Results loaded successfully.
---
batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 62.13it/s]
batch: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 849.02it/s]
lang: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 19.10it/s]
language: big, metrics: accuracy: 0.581085205078125
language: big, metrics: recall@5: 0.8592732548713684
language: big, metrics: mrr: 0.7020400166511536
language: small, metrics: accuracy: 0.445587158203125
language: small, metrics: recall@5: 0.788482666015625
language: small, metrics: mrr: 0.5941007137298584
---
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:02<00:00, 77.87it/s]
lang: small, PPL(T=1): 6.561207288906894, PPL_min(T=1.13): 6.491614799695602
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:02<00:00, 81.50it/s]
lang: big, PPL(T=1): 4.864736317507053, PPL_min(T=1.66): 4.0820464712453255
---
PPLs saved to out/baseline_eval_on_small/ppls.pth

# %%
root@C.12993974:/temp/nanoGPT$ python calculate_metrics_and_save_ppl.py --out_dir=out/out/proposed_margin_1.0_SE_eval_on_small --separated_embeddings=True
Overriding: out_dir = out/out/proposed_margin_1.0_SE_eval_on_small
Overriding: separated_embeddings = True
number of parameters: 10.67M
Results loaded successfully.
---
batch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 62.93it/s]
batch: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 852.15it/s]
lang: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 19.33it/s]
language: big, metrics: accuracy: 0.589599609375
language: big, metrics: recall@5: 0.8564046025276184
language: big, metrics: mrr: 0.7058269381523132
language: small, metrics: accuracy: 0.4541524350643158
language: small, metrics: recall@5: 0.79522705078125
language: small, metrics: mrr: 0.602424681186676
---
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:02<00:00, 78.25it/s]
lang: small, PPL(T=1): 9.799195334465129, PPL_min(T=0.54): 6.5221066556897265
100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:02<00:00, 81.59it/s]
lang: big, PPL(T=1): 5.4067824642636655, PPL_min(T=0.64): 4.346058123631132
---
PPLs saved to out/out/proposed_margin_1.0_SE_eval_on_small/ppls.pth
